# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddings<h1>|
# |<h2>Section:</h2>|<h1>Words to tokens to numbers<h1>|
# |<h2>Lecture:</h2>|<h1><b>Parsing text to numbered tokens<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %% [markdown]
# # Parsing text into words

# %%
# the text
text = [ 'All that we are is the result of what we have thought',
         'To be or not to be that is the question',
         'Be yourself everyone else is already taken' ]

text
# Out:
# ['All that we are is the result of what we have thought',
#  'To be or not to be that is the question',
#  'Be yourself everyone else is already taken']

# %%
# separate into words by splitting by spaces
import re
re.split('\s',text[0])
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Adolphus\AppData\Local\Temp\ipykernel_34636\1325930493.py:3: SyntaxWarning: invalid escape sequence '\s'
#   re.split('\s',text[0])
# ['All',
#  'that',
#  'we',
#  'are',
#  'is',
#  'the',
#  'result',
#  'of',
#  'what',
#  'we',
#  'have',
#  'thought']

# %%
# can recombine into a text
' '.join( re.split('\s',text[0]) )
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Adolphus\AppData\Local\Temp\ipykernel_34636\1857155964.py:2: SyntaxWarning: invalid escape sequence '\s'
#   ' '.join( re.split('\s',text[0]) )
# 'All that we are is the result of what we have thought'

# %%
# also make lower-case
allwords = re.split('\s',' '.join(text).lower())
allwords
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Adolphus\AppData\Local\Temp\ipykernel_34636\2651653478.py:2: SyntaxWarning: invalid escape sequence '\s'
#   allwords = re.split('\s',' '.join(text).lower())
# ['all',
#  'that',
#  'we',
#  'are',
#  'is',
#  'the',
#  'result',
#  'of',
#  'what',
#  'we',
#  'have',
#  'thought',
#  'to',
#  'be',
#  'or',
#  'not',
#  'to',
#  'be',
#  'that',
#  'is',
#  'the',
#  'question',
#  'be',
#  'yourself',
#  'everyone',
#  'else',
#  'is',
#  'already',
#  'taken']

# %% [markdown]
# # Create a vocabulary (lexicon)

# %%
# find the unique words
vocab = sorted(set(allwords))
vocab
# Out:
# ['all',
#  'already',
#  'are',
#  'be',
#  'else',
#  'everyone',
#  'have',
#  'is',
#  'not',
#  'of',
#  'or',
#  'question',
#  'result',
#  'taken',
#  'that',
#  'the',
#  'thought',
#  'to',
#  'we',
#  'what',
#  'yourself']

# %%
print(f'There are {len(allwords)} words in the text, and {len(vocab)} words in the vocabulary')
# Out:
# There are 29 words in the text, and 21 words in the vocabulary

# %% [markdown]
# # Create an encoder and decoder

# %%
# the encoder is a python dictionary type
word2idx = {}
for i,word in enumerate(vocab):
  word2idx[word] = i
word2idx
# Out:
# {'all': 0,
#  'already': 1,
#  'are': 2,
#  'be': 3,
#  'else': 4,
#  'everyone': 5,
#  'have': 6,
#  'is': 7,
#  'not': 8,
#  'of': 9,
#  'or': 10,
#  'question': 11,
#  'result': 12,
#  'taken': 13,
#  'that': 14,
#  'the': 15,
#  'thought': 16,
#  'to': 17,
#  'we': 18,
#  'what': 19,
#  'yourself': 20}

# %%
# and a decoder
idx2word = {}
for i,word in enumerate(vocab):
  idx2word[i] = word
idx2word
# Out:
# {0: 'all',
#  1: 'already',
#  2: 'are',
#  3: 'be',
#  4: 'else',
#  5: 'everyone',
#  6: 'have',
#  7: 'is',
#  8: 'not',
#  9: 'of',
#  10: 'or',
#  11: 'question',
#  12: 'result',
#  13: 'taken',
#  14: 'that',
#  15: 'the',
#  16: 'thought',
#  17: 'to',
#  18: 'we',
#  19: 'what',
#  20: 'yourself'}

# %%
print(f'The word "to" has index {word2idx["to"]}')
print(f'The index "7" maps to the word "{idx2word[7]}"')
# Out:
# The word "to" has index 17
# The index "7" maps to the word "is"

# %% [markdown]
# # Make fake quotes, just for fun :P

# %%
# select random words from the dictionary
import numpy as np
randidx = np.random.randint(0,len(vocab),size=5)

# words of wisdom as a list of tokens
[ idx2word[i] for i in randidx ]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # select random words from the dictionary
# ----> 2 import numpy as np
#       3 randidx = np.random.randint(0,len(vocab),size=5)
#       5 # words of wisdom as a list of tokens
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# does it sound more wise as text??
' '.join([ idx2word[i] for i in randidx ])

# %% [markdown]
# # A peak at tokenization

# %%
# translate the text into numbers
text_as_int = [ word2idx[word] for word in allwords ]
text_as_int

# %%
# and numbers back into text
for tokeni in text_as_int:
  print(f'Token {tokeni:2}: {idx2word[tokeni]}')
